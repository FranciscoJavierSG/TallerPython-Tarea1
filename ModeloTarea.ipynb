# %%
#Abrir el libro
libro = open("Libros_txt_utf-8/En_El_Mar_Remoto.txt","rt",encoding="UTF-8")
print("Se abrió el archivo.")

# %%
#Cantidad total de líneas
variable = len(libro.readlines())+1
print("Cantidad total de líneas: ",variable)

# %%
#Imprimo la posición final
posicion = libro.tell()
print("La posicion del puntero es: ",posicion)

# %%
#Se retorna el puntero al inicio del archivo
libro.seek(0)
print("El puntero volvió el inicio. Ya puede leer el texto nuevamente.")

# %%
#Cantidad total de palabras
data = libro.read()
palabras = data.split()
print("Cantidad total de palabras: ",len(palabras))

# %%
#Cantidad de caracteres con espacio
print("Cantidad de caracteres con espacio: ", len(data))

# %%
#Se retorna el puntero al inicio del archivo
libro.seek(0)
print("El puntero volvió el inicio. Ya puede leer el texto nuevamente. (Por segunda vez xdd)")

# %%
#Cantidad de caracteres sin espacio
x = libro.read()
wea = len(x) - x.count(' ')
print(wea)

# %%
#Repeticiones de todas las palabras 
f = open ('Libros_txt_utf-8/El_Caos_Reptante.txt','r',encoding="utf-8")
data=f.read()
palabras = data.split()
ao='El'
diccionario = dict()

for p in palabras:
    diccionario[p] = diccionario.get(p, 0) + 1

print(diccionario)

# %%
#Palabras no repetidas 
f = open ('Libros_txt_utf-8/El_Caos_Reptante.txt','r',encoding="utf-8")
data=f.read()
f1= data.replace(":","")
f1= f1.replace(",","")


palabras = f1.split()
diccionario = dict()

for p in palabras:
    diccionario[p] = diccionario.get(p, 0) + 1
count = 0
for key in diccionario:
    if diccionario[key] == 1:
        count = count + 1
print(count)
for key, value in diccionario.items():
    if 1== value:
        
        print (key)

# %%
#Menu
def opcion_1(nombre_libro):

    libro = open(nombre_libro,"rt",encoding="UTF-8")
    #Cantidad total de líneas
    variable = len(libro.readlines())+1
    print("Cantidad total de líneas: ",variable)
    libro.seek(0)
    #Cantidad total de palabras
    data = libro.read()
    palabras = data.split()
    print("Cantidad total de palabras: ",len(palabras))
    #Palabras no repetidas 
    libro.seek(0)
    f = open (nombre_libro,'r',encoding="utf-8")
    data=f.read()
    f1= data.replace(":","")
    f1= f1.replace(",","")

    palabras = f1.split()
    diccionario = dict()

    for p in palabras:
        diccionario[p] = diccionario.get(p, 0) + 1
    count = 0
    for key in diccionario:
        if diccionario[key] == 1:
            count = count + 1
    print("Número de palabras no repetidas", count)    
    #Cantidad de caracteres con espacio
    print("Cantidad de caracteres con espacio: ", len(data))
    #Cantidad de caracteres sin espacio
    libro.seek(0)
    leer = libro.read()
    sin_espacio = len(leer) - leer.count(' ')
    print("Cantidad de caracteres sin espacio ", sin_espacio)
    print("\n ")

def opcion_2(nombre_libro):
    libro = open(nombre_libro,"rt",encoding="UTF-8")
    #Se retorna el puntero al inicio del archivo
    libro.seek(0)
    #Revisa si la palabra esta en el texto, de si existir la imprime, falta ver cuantas veces se repite 
    #ahora lo hago
    leer = libro.read()
    palabra = input("Ingrese la palabra a buscar:")
    if palabra in leer:
        print ("Palabra:"+palabra)
        print ("Se encuentra:",leer.count(palabra)," veces\n")
    else:
        print("no esta la palabra en el texto\n")

def opcion_3(nombre_libro):
    libro = open(nombre_libro,"rt",encoding="UTF-8")
    print("Ingrese la palabra a reemplazar")
    libro.seek(0)
    palabra_buscar = input()

    print("Ingrese la palabra que reemplazará a '"+palabra_buscar+"'")
    palabra_reemplazar = input()

    with open(nombre_libro, 'r') as file:
        filedata = file.read()
        filedata = filedata.replace(palabra_buscar, palabra_reemplazar)
    with open(nombre_libro, 'w') as file:
        file.write(filedata)

def numero():
 
    num=0
    ingreso=False
  
    while(not ingreso):  
        try:
            num = int(input("Ingrese la opcion que desee: "))
            if num>=1 & num<=7:
                ingreso=True
        except ValueError:
            print('Error, introduce una opción válida')

    return num

salir = False
opcion = 0
 
while not salir:

    print ("------------------------------------")
    print ("1. El árbol de la colina")
    print ("2. El caos reptante")
    print ("3. En el mar remoto")
    print ("4. Lazarillo de Tormes")
    print ("5. Para leer al atardecer")
    print ("6. Una corta historia del eBook")
    print ("7. Salir")
    print ("------------------------------------") 
    print ("Elige una opcion\n")
    
    opcion = numero()

    if opcion == 1:
        salir = False
        opcion = 0
        nombre_libro = "Libros_txt_utf-8/El_Arbol_De_La_Colina.txt"
        while not salir:
            print ("El árbol de la colina")
            print ("------------------------------------")
            print ("1. Entregar una estadística del documento")
            print ("2. Buscar una palabra en el documento y las veces que esta repetida")
            print ("3. Reemplazar una palabra en el texto.")
            print ("4. Salir")
            print ("------------------------------------")
            print ("Elige una opcion\n")
           
            opcion = numero()
            if opcion == 1:
                opcion_1(nombre_libro)
            elif opcion == 2:
                opcion_2(nombre_libro)
            elif opcion == 3:
                opcion_3(nombre_libro)
            elif opcion == 4:
                salir = True
                print ("Fin")

    elif opcion == 2:
        salir = False
        opcion = 0
        #cambiar nombre para cada opcion de libro
        nombre_libro = "Libros_txt_utf-8/El_Caos_Reptante.txt"
        while not salir:
            print ("El caos reptante")
            print ("------------------------------------")
            print ("1. Entregar una estadística del documento")
            print ("2. Buscar una palabra en el documento y las veces que esta repetida")
            print ("3. Reemplazar una palabra en el texto.")
            print ("4. Salir")
            print ("------------------------------------")
            print ("Elige una opcion\n")
           
            opcion = numero()
            if opcion == 1:
                opcion_1(nombre_libro)
            elif opcion == 2:
                opcion_2(nombre_libro)
            elif opcion == 3:
                opcion_3(nombre_libro)
            elif opcion == 4:
                salir = True
                print ("Fin")
    elif opcion == 3:
        salir = False
        opcion = 0
         #cambiar nombre para cada opcion de libro
        nombre_libro = "Libros_txt_utf-8/En_El_Mar_Remoto.txt"
        while not salir:
            print ("En el mar remoto")
            print ("------------------------------------")
            print ("1. Entregar una estadística del documento")
            print ("2. Buscar una palabra en el documento y las veces que esta repetida")
            print ("3. Reemplazar una palabra en el texto.")
            print ("4. Salir")
            print ("------------------------------------")
            print ("Elige una opcion\n")
           
            opcion = numero()
            if opcion == 1:
                opcion_1(nombre_libro)
            elif opcion == 2:
                opcion_2(nombre_libro)            
            elif opcion == 3:
                opcion_3(nombre_libro)
            elif opcion == 4:
                salir = True
                print ("Fin")
    elif opcion == 4:
        salir = False
        opcion = 0
        #cambiar nombre para cada opcion de libro
        nombre_libro = "Libros_txt_utf-8/Lazarillo_de_Tormes.txt"
        while not salir:
            print ("Lazarillo de Tormes")
            print ("------------------------------------")
            print ("1. Entregar una estadística del documento")
            print ("2. Buscar una palabra en el documento y las veces que esta repetida")
            print ("3. Reemplazar una palabra en el texto.")
            print ("4. Salir")
            print ("------------------------------------")
            print ("Elige una opcion\n")
           
            opcion = numero()
            if opcion == 1:
                opcion_1(nombre_libro) 
            elif opcion == 2:
                opcion_2(nombre_libro)
            elif opcion == 3:
               opcion_3(nombre_libro)
            elif opcion == 4:
                salir = True
                print ("Fin")
    
    elif opcion == 5:
        salir = False
        opcion = 0
        #cambiar nombre para cada opcion de libro
        nombre_libro = "Libros_txt_utf-8/Para_Leer_Al_Atardecer.txt"
        while not salir:
            print ("Para leer al atardecer")
            print ("------------------------------------")
            print ("1. Entregar una estadística del documento")
            print ("2. Buscar una palabra en el documento y las veces que esta repetida")
            print ("3. Reemplazar una palabra en el texto.")
            print ("4. Salir")
            print ("------------------------------------")
            print ("Elige una opcion\n")
           
            opcion = numero()
            if opcion == 1:
                opcion_1(nombre_libro)  
            elif opcion == 2:
                opcion_2(nombre_libro)
            elif opcion == 3:
                opcion_3(nombre_libro)
            elif opcion == 4:
                salir = True
                print ("Fin")
    
    elif opcion == 6:
        salir = False
        opcion = 0
        #cambiar nombre para cada opcion de libro
        nombre_libro = "Libros_txt_utf-8/Una_corta_historia_del_eBook.txt"
        while not salir:
            print ("Una corta historia del eBook")
            print ("------------------------------------")
            print ("1. Entregar una estadística del documento")
            print ("2. Buscar una palabra en el documento y las veces que esta repetida")
            print ("3. Reemplazar una palabra en el texto.")
            print ("4. Salir")
            print ("------------------------------------")
            print ("Elige una opcion\n")
           
            opcion = numero()
            if opcion == 1:
                opcion_1(nombre_libro)
            elif opcion == 2:
                opcion_2(nombre_libro)
            elif opcion == 3:
                opcion_3(nombre_libro)
            elif opcion == 4:
                salir = True
                print ("Fin")

    elif opcion == 7:
        salir = True
        print ("Fin")
    else:
        print ("Introduce una opción válida.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\chont\Documents\GitHub\TallerPython-Tarea1\a.ipynb Cell 11' in <cell line: 86>()
#     <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=213'>214</a> print ("------------------------------------")
#     <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=214'>215</a> print ("Elige una opcion\n")
# --> <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=216'>217</a> opcion = numero()
#     <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=217'>218</a> if opcion == 1:
#     <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=218'>219</a>     opcion_1(nombre_libro)
#
# c:\Users\chont\Documents\GitHub\TallerPython-Tarea1\a.ipynb Cell 11' in numero()
#      <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=72'>73</a> while(not ingreso):
#      <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=73'>74</a>     try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=74'>75</a>         num = int(input("Ingrese la opcion que desee: "))
#      <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=75'>76</a>         if num>=1 & num<=7:
#      <a href='vscode-notebook-cell:/c%3A/Users/chont/Documents/GitHub/TallerPython-Tarea1/a.ipynb#ch0000010?line=76'>77</a>             ingreso=True
#
# File ~\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelbase.py:1159, in Kernel.raw_input(self, prompt)
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1154'>1155</a> if not self._allow_stdin:
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1155'>1156</a>     raise StdinNotImplementedError(
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1156'>1157</a>         "raw_input was called, but this frontend does not support input requests."
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1157'>1158</a>     )
# -> <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1158'>1159</a> return self._input_request(
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1159'>1160</a>     str(prompt),
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1160'>1161</a>     self._parent_ident["shell"],
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1161'>1162</a>     self.get_parent("shell"),
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1162'>1163</a>     password=False,
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1163'>1164</a> )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\ipykernel\kernelbase.py:1201, in Kernel._input_request(self, prompt, ident, parent, password)
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1197'>1198</a>             break
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1198'>1199</a> except KeyboardInterrupt:
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1199'>1200</a>     # re-raise KeyboardInterrupt, to truncate traceback
# -> <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1200'>1201</a>     raise KeyboardInterrupt("Interrupted by user") from None
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1201'>1202</a> except Exception:
#    <a href='file:///~/AppData/Roaming/Python/Python38/site-packages/ipykernel/kernelbase.py?line=1202'>1203</a>     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#Se retorna el puntero al inicio del archivo
libro.seek(0)
print("El puntero volvió el inicio. Ya puede leer el texto nuevamente. (Por tercera vez xdd)")

# %%
# Punto 3: Reemplazar una palabra en un texto
print("Ingrese la palabra a reemplazar")
palabra_buscar = input()

print("Ingrese la palabra que reemplazará a '"+palabra_buscar+"'")
palabra_reemplazar = input()

with open('ejemplo.txt', 'r') as file:
    filedata = file.read()
    filedata = filedata.replace(palabra_buscar, palabra_reemplazar)
with open('ejemplo.txt', 'w') as file:
    file.write(filedata)
    
print("Listoco")
